# %% [markdown]
# # リポジトリクローン

# %%
# !git clone https://github.com/caiyuanhao1998/Retinexformer
# %cd Retinexformer

# %% [markdown]
# # パッケージインストール

# %%
# !pip install -q lmdb onnx

# %% [markdown]
# # 変換スクリプトダウンロード

# %%
# !wget https://github.com/Kazuhito00/Retinexformer-ONNX-Sample/raw/refs/heads/main/download_pretrained_models.py
# !wget https://github.com/Kazuhito00/Retinexformer-ONNX-Sample/raw/refs/heads/main/export_all_onnx.py

# %% [markdown]
# # 訓練済み重みダウンロード

# %%
# !python download_pretrained_models.py --force

# %% [markdown]
# # ONNX変換

# %%
# !python export_all_onnx.py

# %%
# !zip -r onnx_models.zip onnx_models

# %%
from google.colab import files
files.download("onnx_models.zip")
